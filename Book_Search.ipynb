# %% [markdown]
# Collection of methods used to pull down openlibrary data dump and get cover image embeddings using OpenAI's Clip model

# %%
import pandas as pd
import requests
import os
import gzip
import json
import numpy as np

import pprint
import tempfile

from typing import Dict, Text

from ast import literal_eval

# import faiss
import torch
import skimage
# import pinecone
import numpy as np
import pandas as pd
from PIL import Image
from io import BytesIO
import IPython.display
import matplotlib.pyplot as plt
# from datasets import load_dataset
from collections import OrderedDict
from transformers import CLIPProcessor, CLIPModel, CLIPTokenizer

# %%
import PIL

PIL.Image.MAX_IMAGE_PIXELS = None

# %% [markdown]
# [link text](https://)Step 1: Download data dump from https://openlibrary.org/data; process in batches with pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def download_data_dump():
  chunk_size = 1000000  # Adjust the chunk size as needed
  file_path = '/content/drive/MyDrive/book_data/ol_dump_editions_latest.txt.gz'  # Replace with the path to your large file


  # Read and process each chunk, then output to separate files
  for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size, compression='gzip', header=0, sep='\t', quotechar='"')):
      output_file_path = f'/content/drive/MyDrive/book_data/processed_batches/processed_chunk_{i + 1}.csv'
      chunk.to_csv(output_file_path, index=False)

      print(f"Processed chunk {i + 1}. Output saved to {output_file_path}")

# %%
download_data_dump()
# Out:
# Processed chunk 1. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_1.csv
# Processed chunk 2. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_2.csv
# Processed chunk 3. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_3.csv
# Processed chunk 4. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_4.csv
# Processed chunk 5. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_5.csv
# Processed chunk 6. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_6.csv
# Processed chunk 7. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_7.csv
# Processed chunk 8. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_8.csv
# Processed chunk 9. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_9.csv
# Processed chunk 10. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_10.csv
# Processed chunk 11. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_11.csv
# Processed chunk 12. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_12.csv
# Processed chunk 13. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_13.csv
# Processed chunk 14. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_14.csv
# Processed chunk 15. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_15.csv
# Processed chunk 16. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_16.csv
# Processed chunk 17. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_17.csv
# Processed chunk 18. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_18.csv
# Processed chunk 19. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_19.csv
# Processed chunk 20. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_20.csv
# Processed chunk 21. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_21.csv
# Processed chunk 22. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_22.csv
# Processed chunk 23. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_23.csv
# Processed chunk 24. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_24.csv
# Processed chunk 25. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_25.csv
# Processed chunk 26. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_26.csv
# Processed chunk 27. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_27.csv
# Processed chunk 28. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_28.csv
# Processed chunk 29. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_29.csv
# Processed chunk 30. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_30.csv
# Processed chunk 31. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_31.csv
# Processed chunk 32. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_32.csv
# Processed chunk 33. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_33.csv
# Processed chunk 34. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_34.csv
# Processed chunk 35. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_35.csv
# Processed chunk 36. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_36.csv
# Processed chunk 37. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_37.csv
# Processed chunk 38. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_38.csv
# Processed chunk 39. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_39.csv
# Processed chunk 40. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_40.csv
# Processed chunk 41. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_41.csv
# Processed chunk 42. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_42.csv
# Processed chunk 43. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_43.csv
# Processed chunk 44. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_44.csv
# Processed chunk 45. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_45.csv
# Processed chunk 46. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_46.csv
# Processed chunk 47. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_47.csv
# Processed chunk 48. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_48.csv
# Processed chunk 49. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_49.csv
# Processed chunk 50. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_50.csv
# Processed chunk 51. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_51.csv
# Processed chunk 52. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_52.csv
# Processed chunk 53. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_53.csv
# Processed chunk 54. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_54.csv
# Processed chunk 55. Output saved to /content/drive/MyDrive/book_data/processed_batches/processed_chunk_55.csv

# %%
def process_raw_files():
  # Directory where processed chunk files are stored
  processed_chunks_dir = '/content/drive/MyDrive/book_data/processed_batches/'  # Replace with the path to your directory
  select_columns = ['title', 'isbn_10', 'isbn_13', 'publish_date', 'key', 'subjects', 'languages', 'description.value', 'genres']

  # List to store DataFrames of processed chunks
  processed_chunks = []

  # Column names for your DataFrame
  column_names = ['col1', 'col2', 'col3', 'col4', 'col5']  # original data tab separated columns

  # Read each processed chunk file and append to the list
  for i, filename in enumerate(os.listdir(processed_chunks_dir)):
      if filename.endswith('.csv'):
          print(f'Processing file {filename}....')
          file_path = os.path.join(processed_chunks_dir, filename)
          chunk_df = pd.read_csv(file_path, names=column_names)
          books_info_lst = chunk_df['col5'].tolist()

          # raw data stored in column as json
          books_info_lst = [json.loads(book_record) for book_record in books_info_lst]
          books_df = pd.json_normalize(books_info_lst)

          # narrow down amount of data by only outputting english language books and books greater than 100 pages
          books_df['languages_unpacked'] = books_df['languages'].apply(lambda lst: ', '.join(d['key'] for d in lst) if isinstance(lst, list) else '')
          df_languages_keys = books_df[books_df['languages_unpacked'] =='/languages/eng']
          df_page_cnt_filter = df_languages_keys[df_languages_keys['number_of_pages'] >= 100]

          final_df = df_page_cnt_filter
          final_df = final_df[select_columns]
          final_df.to_csv(f'/content/drive/MyDrive/book_data/all_raw/books_{i}.csv')

# %%
process_raw_files()
# Out:
# Processing file processed_chunk_1.csv....
# Processing file processed_chunk_2.csv....
# Processing file processed_chunk_3.csv....
# Processing file processed_chunk_4.csv....
# Processing file processed_chunk_5.csv....
# Processing file processed_chunk_6.csv....
# Processing file processed_chunk_7.csv....
# Processing file processed_chunk_8.csv....
# Processing file processed_chunk_9.csv....
# Processing file processed_chunk_10.csv....
# Processing file processed_chunk_11.csv....
# Processing file processed_chunk_12.csv....
# Processing file processed_chunk_13.csv....
# Processing file processed_chunk_14.csv....
# Processing file processed_chunk_15.csv....
# Processing file processed_chunk_16.csv....
# Processing file processed_chunk_17.csv....
# Processing file processed_chunk_18.csv....
# Processing file processed_chunk_19.csv....
# Processing file processed_chunk_20.csv....
# Processing file processed_chunk_21.csv....
# Processing file processed_chunk_22.csv....
# Processing file processed_chunk_23.csv....
# Processing file processed_chunk_24.csv....
# Processing file processed_chunk_25.csv....
# Processing file processed_chunk_26.csv....
# Processing file processed_chunk_27.csv....
# Processing file processed_chunk_28.csv....
# Processing file processed_chunk_29.csv....
# Processing file processed_chunk_30.csv....
# Processing file processed_chunk_31.csv....
# Processing file processed_chunk_32.csv....
# Processing file processed_chunk_33.csv....
# Processing file processed_chunk_34.csv....
# Processing file processed_chunk_35.csv....
# Processing file processed_chunk_36.csv....
# Processing file processed_chunk_37.csv....
# Processing file processed_chunk_38.csv....
# Processing file processed_chunk_39.csv....
# Processing file processed_chunk_40.csv....
# Processing file processed_chunk_41.csv....
# Processing file processed_chunk_42.csv....
# Processing file processed_chunk_43.csv....
# Processing file processed_chunk_44.csv....
# Processing file processed_chunk_45.csv....
# Processing file processed_chunk_46.csv....
# Processing file processed_chunk_47.csv....
# Processing file processed_chunk_48.csv....
# Processing file processed_chunk_49.csv....
# Processing file processed_chunk_50.csv....
# Processing file processed_chunk_51.csv....
# Processing file processed_chunk_52.csv....
# Processing file processed_chunk_53.csv....
# Processing file processed_chunk_54.csv....
# Processing file processed_chunk_55.csv....

# %% [markdown]
# Step 2: Read in full data dump and filter for desired data (in this case recent (between 2020-2023) adult fiction

# %%
def read_csvs_in_directory(directory):
    dataframes = []
    for filename in os.listdir(directory):
        print(f'Processing file {filename}....')
        if filename.endswith(".csv"):
            csv_path = os.path.join(directory, filename)
            books_df = pd.read_csv(csv_path)

            dataframes.append(books_df)
    # return dataframes
    return pd.concat(dataframes, ignore_index=True)

# %%
read_csvs_in_directory (all_raw)
# Out:
# Processing file books_0.csv....
# Processing file books_1.csv....
# Processing file books_2.csv....
# Processing file books_3.csv....
# Processing file books_4.csv....
# Processing file books_5.csv....
# Processing file books_6.csv....
# Processing file books_7.csv....
# Processing file books_8.csv....
# Processing file books_9.csv....
# Processing file books_10.csv....
# Processing file books_11.csv....
# Processing file books_12.csv....
# Processing file books_13.csv....
# Processing file books_14.csv....
# Processing file books_15.csv....
# Processing file books_16.csv....
# Processing file books_17.csv....
# Processing file books_18.csv....
# Processing file books_19.csv....
# Processing file books_20.csv....
# Processing file books_21.csv....
# Processing file books_22.csv....
# Processing file books_23.csv....
# Processing file books_24.csv....
# Processing file books_25.csv....
# Processing file books_26.csv....
# Processing file books_27.csv....
# Processing file books_28.csv....
# Processing file books_29.csv....
# Processing file books_30.csv....
# Processing file books_31.csv....
# Processing file books_32.csv....
# Processing file books_33.csv....
# Processing file books_34.csv....
# Processing file books_35.csv....
# Processing file books_36.csv....
# Processing file books_37.csv....
# Processing file books_38.csv....
# Processing file books_39.csv....
# Processing file books_40.csv....
# Processing file books_41.csv....
# Processing file books_42.csv....
# Processing file books_43.csv....
# Processing file books_44.csv....
# Processing file books_45.csv....
# Processing file books_46.csv....
# Processing file books_47.csv....
# Processing file books_48.csv....
# Processing file books_49.csv....
# Processing file books_50.csv....
# Processing file books_51.csv....
# Processing file books_52.csv....
# Processing file books_53.csv....
# Processing file books_54.csv....
#           Unnamed: 0                                              title  \
# 0                  4               Encyclopedia of designs for quilting
# 1                  9         Peacemaking strategies in Northern Ireland
# 2                 34                         Musicology and performance
# 3                 40              The return of the wolf to Yellowstone
# 4                 48                  The Mystery of the Secret Message
# ...              ...                                                ...
# 12745832      308028  Isolation, characterization, and utilization o...
# 12745833      308032  An investigation into the thought of Kōgyō D...
# 12745834      308038                                Turn the cup around
# 12745835      308040                         Abnormal illness behaviour
# 12745836      308047  Valperga, or, The life and adventures of Castr...
#
#                                isbn_10 isbn_13 publish_date  \
# 0                       ['0891458875']     NaN         1996
# 1                       ['0312163460']     NaN         1997
# 2                       ['0300068050']     NaN         1997
# 3                       ['0805031014']     NaN         1997
# 4         ['0807554294', '0807554308']     NaN         1996
# ...                                ...     ...          ...
# 12745832                ['3540616969']     NaN         1997
# 12745833                           NaN     NaN         1998
# 12745834                ['0385322925']     NaN         1997
# 12745835                ['0471965731']     NaN         1997
# 12745836  ['0195108817', '0195108825']     NaN         1997
#
#                         key  \
# 0         /books/OL1000121M
# 1         /books/OL1000199M
# 2         /books/OL1000711M
# 3         /books/OL1000771M
# 4         /books/OL1000890M
# ...                     ...
# 12745832   /books/OL999641M
# 12745833    /books/OL99967M
# 12745834   /books/OL999767M
# 12745835   /books/OL999781M
# 12745836   /books/OL999878M
#
#                                                    subjects  \
# 0                                 ['Quilting -- Patterns.']
# 1         ['Conflict management -- Northern Ireland.', '...
# 2         ['Music -- History and criticism', 'Musicology...
# 3         ['Wolves -- Reintroduction -- Yellowstone Nati...
# 4         ['Brothers and sisters -- Fiction.', 'Orphans ...
# ...                                                     ...
# 12745832  ['Developmental neurophysiology.', 'Neural ste...
# 12745833                                                NaN
# 12745834  ['Grandmothers -- Fiction.', 'Brothers and sis...
# 12745835  ['Somatoform disorders.', 'Hypochondriasis -- ...
# 12745836  ['Castracani, Castruccio, 1281-1328 -- Fiction...
#
#                             languages  \
# 0         [{'key': '/languages/eng'}]
# 1         [{'key': '/languages/eng'}]
# 2         [{'key': '/languages/eng'}]
# 3         [{'key': '/languages/eng'}]
# 4         [{'key': '/languages/eng'}]
# ...                               ...
# 12745832  [{'key': '/languages/eng'}]
# 12745833  [{'key': '/languages/eng'}]
# 12745834  [{'key': '/languages/eng'}]
# 12745835  [{'key': '/languages/eng'}]
# 12745836  [{'key': '/languages/eng'}]
#
#                                           description.value genres
# 0                                                       NaN    NaN
# 1         Competing theories of conflict management can ...    NaN
# 2         Arriving in the United States at age twenty-se...    NaN
# 3                                                       NaN    NaN
# 4         While helping their grandfather prepare for Gr...    NaN
# ...                                                     ...    ...
# 12745832  In trying to understand postnatal neurogenesis...    NaN
# 12745833                                                NaN    NaN
# 12745834  Mysterious paintings in a cave near her grandm...    NaN
# 12745835                                                NaN    NaN
# 12745836                                                NaN    NaN
#
# [12745837 rows x 10 columns]

# %%
def get_image_id(row):
    isbn_10 = row['isbn_10']
    isbn_13 = row['isbn_13']
    image_id = None
    if isbn_10 is not np.nan:
        image_id = literal_eval(isbn_10)[0]
    elif isbn_13 is not np.nan:
        image_id = literal_eval(isbn_13)[0]

    return image_id

# %%
def get_image_url(image_id):
  if image_id:
    return f'https://covers.openlibrary.org/b/isbn/{image_id}.jpg'
  return None

# %%
def get_filtered_data():
  parent_directory = '/content/drive/MyDrive/book_data/all_raw'
  result_df = read_csvs_in_directory(parent_directory)
  fiction_df = result_df[result_df['subjects'].fillna('').str.contains('Fiction', case=False)]

  adult_fiction_df = fiction_df[~fiction_df['subjects'].str.contains('Juvenile', case=False)]

  recent_fiction_df = adult_fiction_df[adult_fiction_df['publish_date'].fillna('').str.contains('|'.join(['2020', '2021', '2022', '2023']), case=False)]

  # get image id which is isbn_13 or isbn_13 code then use to build urls

  recent_fiction_df['image_id'] = recent_fiction_df.apply(get_image_id, axis=1)
  recent_fiction_df['image_url'] = recent_fiction_df['image_id'].apply(get_image_url)

  recent_fiction_df = recent_fiction_df[recent_fiction_df['image_url'].notna()]

  recent_fiction_df.to_csv('/content/drive/MyDrive/book_data/recent_fiction.csv')

# %%
# Execute this cell
get_filtered_data()
# Out:
# Processing file books_0.csv....
# Processing file books_1.csv....
# Processing file books_2.csv....
# Processing file books_3.csv....
# Processing file books_4.csv....
# Processing file books_5.csv....
# Processing file books_6.csv....
# Processing file books_7.csv....
# Processing file books_8.csv....
# Processing file books_9.csv....
# Processing file books_10.csv....
# Processing file books_11.csv....
# Processing file books_12.csv....
# Processing file books_13.csv....
# Processing file books_14.csv....
# Processing file books_15.csv....
# Processing file books_16.csv....
# Processing file books_17.csv....
# Processing file books_18.csv....
# Processing file books_19.csv....
# Processing file books_20.csv....
# Processing file books_21.csv....
# Processing file books_22.csv....
# Processing file books_23.csv....
# Processing file books_24.csv....
# Processing file books_25.csv....
# Processing file books_26.csv....
# Processing file books_27.csv....
# Processing file books_28.csv....
# Processing file books_29.csv....
# Processing file books_30.csv....
# Processing file books_31.csv....
# Processing file books_32.csv....
# Processing file books_33.csv....
# Processing file books_34.csv....
# Processing file books_35.csv....
# Processing file books_36.csv....
# Processing file books_37.csv....
# Processing file books_38.csv....
# Processing file books_39.csv....
# Processing file books_40.csv....
# Processing file books_41.csv....
# Processing file books_42.csv....
# Processing file books_43.csv....
# Processing file books_44.csv....
# Processing file books_45.csv....
# Processing file books_46.csv....
# Processing file books_47.csv....
# Processing file books_48.csv....
# Processing file books_49.csv....
# Processing file books_50.csv....
# Processing file books_51.csv....
# Processing file books_52.csv....
# Processing file books_53.csv....
# Processing file books_54.csv....
# <ipython-input-38-863235399>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_fiction_df['image_id'] = recent_fiction_df.apply(get_image_id, axis=1)
# <ipython-input-38-863235399>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_fiction_df['image_url'] = recent_fiction_df['image_id'].apply(get_image_url)

# %% [markdown]
# Step 3: Batch through filtered dataset, pull down images, and save embeddings

# %%
def get_image(image_URL):
  if image_URL:
    try:
      response = requests.get(image_URL)
      image = Image.open(BytesIO(response.content)).convert("RGB")
      width, height = image.size
      if width == 1 and height == 1:
        return None
      return image
    except:
      print(f"Error: {image_URL}")
      return None
    return None

# %%
def get_embedding_batch(images):

  model_ID = "openai/clip-vit-base-patch32"
  device = "cuda" if torch.cuda.is_available() else "cpu"

  model = CLIPModel.from_pretrained(model_ID).to(device)
  processor = CLIPProcessor.from_pretrained(model_ID)
      # Get the tokenizer
  tokenizer = CLIPTokenizer.from_pretrained(model_ID)

  try:
    batch_tensor = torch.stack([processor(images=img, return_tensors="pt", padding=True)['pixel_values'][0] for img in images])
    embedding = model.get_image_features(batch_tensor)

    return embedding.cpu().detach().numpy()
  except:
      print(f'Error: image in batch does not exist or cannot be downloaded')
      return []
  return []

# %%
def batch_process_get_embeddings():
  filtered_df = pd.read_csv('/content/drive/MyDrive/book_data/recent_fiction.csv')
  directory_path = '/content/drive/MyDrive/book_data/batched_embeddings/'
  directory_files = os.listdir(directory_path)

  # get iterator starting point from file name to kick process off at file where it failed
  latest_ind = 0
  if len(directory_files) > 0:
    latest_file = sorted(directory_files)[len(directory_files) - 1]
    latest_ind = int(latest_file.split('_')[1])

  step_size = 100
  images = []
  selected_rows = None
  for start_row in range(latest_ind, 10000, step_size):
      print(f'Processing from row {start_row}')
      # Calculate the end row for each iteration
      end_row = min(start_row + step_size - 1, len(filtered_df) - 1)

      # Get the group of rows for the current iteration
      selected_rows = filtered_df.iloc[start_row:end_row + 1]


      image_embedding_df_cols = ['key', 'image']


      selected_rows["image"] = selected_rows[str("image_url")].apply(get_image)

      image_df = selected_rows[selected_rows['image'].notna()]
      image_df = image_df[image_embedding_df_cols]


      image_embeddings = []
      chunk_size = 5
      for i in range(0, len(image_df['image'].values), chunk_size):
        print(f'Processing images from {i}')
        chunk_df = image_df.iloc[i:i + chunk_size]

        chunk_embeddings = get_embedding_batch(chunk_df['image'].values)

        image_embeddings.extend(list(chunk_embeddings))



      image_df['image_embeddings'] = list(image_embeddings)


      merged_df = pd.merge(selected_rows, image_df, on='key', how='left')


      merged_df.to_csv(f'/content/drive/MyDrive/book_data/batched_embeddings/{start_row}_{start_row + step_size}_w_embeddings.csv')

# %%
batch_process_get_embeddings()
# Out:
# Processing from row 7800
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Saved batch 7800 to 7900
# Processing from row 7900
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Saved batch 7900 to 8000
# Processing from row 8000
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Saved batch 8000 to 8100
# Processing from row 8100
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Processing images from 50
# Saved batch 8100 to 8200
# Processing from row 8200
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Processing images from 50
# Saved batch 8200 to 8300
# Processing from row 8300
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Saved batch 8300 to 8400
# Processing from row 8400
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json
# WARNING:huggingface_hub.utils._http:HTTP Error 429 thrown while requesting HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Retrying in 1s [Retry 1/5].
# Processing images from 0
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json
# WARNING:huggingface_hub.utils._http:HTTP Error 429 thrown while requesting HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json
# Retrying in 2s [Retry 2/5].
# WARNING:huggingface_hub.utils._http:Retrying in 2s [Retry 2/5].
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Saved batch 8400 to 8500
# Processing from row 8500
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Saved batch 8500 to 8600
# Processing from row 8600
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Saved batch 8600 to 8700
# Processing from row 8700
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Saved batch 8700 to 8800
# Processing from row 8800
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Saved batch 8800 to 8900
# Processing from row 8900
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Saved batch 8900 to 9000
# Processing from row 9000
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Saved batch 9000 to 9100
# Processing from row 9100
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Saved batch 9100 to 9200
# Processing from row 9200
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Saved batch 9200 to 9300
# Processing from row 9300
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Saved batch 9300 to 9400
# Processing from row 9400
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Saved batch 9400 to 9500
# Processing from row 9500
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Saved batch 9500 to 9600
# Processing from row 9600
# Processing images from 0
# Processing images from 5
# Processing images from 10
# Processing images from 15
# Processing images from 20
# Processing images from 25
# Processing images from 30
# Processing images from 35
# Processing images from 40
# Processing images from 45
# Saved batch 9600 to 9689
# Batch processing complete (up to row 10000 or total rows).

# %%
def read_csvs_in_directory(directory):
    dataframes = []
    for filename in os.listdir(directory):
        print(f'Processing file {filename}....')
        if filename.endswith(".csv"):
            csv_path = os.path.join(directory, filename)
            books_df = pd.read_csv(csv_path)

            dataframes.append(books_df)
    # return dataframes
    return pd.concat(dataframes, ignore_index=True)

# %%
def pkl_embeddings():
  result_df = read_csvs_in_directory('/content/drive/MyDrive/book_data/batched_embeddings/')
  result_df['image_embeddings'] = result_df['image_embeddings'].str.strip('[]').str.split().apply(lambda x: np.array(x).astype(float)).to_numpy()
  image_df = result_df[result_df['image_embeddings'].notna()]
  image_df['image_embeddings'] = image_df['image_embeddings'].apply(lambda x: x.reshape(1, -1))

  image_df = image_df[image_df['image_embeddings'].notna()]

  image_df.to_pickle('/content/drive/MyDrive/book_data/image_embeddings.pkl');

# %%
 pkl_embeddings()
# Out:
# Processing file 0_100_w_embeddings.csv....
# Processing file 100_200_w_embeddings.csv....
# Processing file 200_300_w_embeddings.csv....
# Processing file 300_400_w_embeddings.csv....
# Processing file 400_500_w_embeddings.csv....
# Processing file 500_600_w_embeddings.csv....
# Processing file 600_700_w_embeddings.csv....
# Processing file 700_800_w_embeddings.csv....
# Processing file 800_900_w_embeddings.csv....
# Processing file 900_1000_w_embeddings.csv....
# Processing file 1000_1100_w_embeddings.csv....
# Processing file 1100_1200_w_embeddings.csv....
# Processing file 1200_1300_w_embeddings.csv....
# Processing file 1300_1400_w_embeddings.csv....
# Processing file 1400_1500_w_embeddings.csv....
# Processing file 1500_1600_w_embeddings.csv....
# Processing file 1600_1700_w_embeddings.csv....
# Processing file 1700_1800_w_embeddings.csv....
# Processing file 1800_1900_w_embeddings.csv....
# Processing file 1900_2000_w_embeddings.csv....
# Processing file 2000_2100_w_embeddings.csv....
# Processing file 2100_2200_w_embeddings.csv....
# Processing file 2200_2300_w_embeddings.csv....
# Processing file 2300_2400_w_embeddings.csv....
# Processing file 2400_2500_w_embeddings.csv....
# Processing file 2500_2600_w_embeddings.csv....
# Processing file 2600_2700_w_embeddings.csv....
# Processing file 2700_2800_w_embeddings.csv....
# Processing file 2800_2900_w_embeddings.csv....
# Processing file 2900_3000_w_embeddings.csv....
# Processing file 3000_3100_w_embeddings.csv....
# Processing file 3100_3200_w_embeddings.csv....
# Processing file 3200_3300_w_embeddings.csv....
# Processing file 3300_3400_w_embeddings.csv....
# Processing file 3400_3500_w_embeddings.csv....
# Processing file 3500_3600_w_embeddings.csv....
# Processing file 3600_3700_w_embeddings.csv....
# Processing file 3700_3800_w_embeddings.csv....
# Processing file 3800_3900_w_embeddings.csv....
# Processing file 3900_4000_w_embeddings.csv....
# Processing file 4000_4100_w_embeddings.csv....
# Processing file 4100_4200_w_embeddings.csv....
# Processing file 4200_4300_w_embeddings.csv....
# Processing file 4300_4400_w_embeddings.csv....
# Processing file 4400_4500_w_embeddings.csv....
# Processing file 4500_4600_w_embeddings.csv....
# Processing file 4600_4700_w_embeddings.csv....
# Processing file 4700_4800_w_embeddings.csv....
# Processing file 4800_4900_w_embeddings.csv....
# Processing file 4900_5000_w_embeddings.csv....
# Processing file 5000_5100_w_embeddings.csv....
# Processing file 5100_5200_w_embeddings.csv....
# Processing file 5200_5300_w_embeddings.csv....
# Processing file 5300_5400_w_embeddings.csv....
# Processing file 5400_5500_w_embeddings.csv....
# Processing file 5500_5600_w_embeddings.csv....
# Processing file 5600_5700_w_embeddings.csv....
# Processing file 5700_5800_w_embeddings.csv....
# Processing file 5800_5900_w_embeddings.csv....
# Processing file 5900_6000_w_embeddings.csv....
# Processing file 6000_6100_w_embeddings.csv....
# Processing file 6100_6200_w_embeddings.csv....
# Processing file 6200_6300_w_embeddings.csv....
# Processing file 6300_6400_w_embeddings.csv....
# Processing file 6400_6500_w_embeddings.csv....
# Processing file 6500_6600_w_embeddings.csv....
# Processing file 6600_6700_w_embeddings.csv....
# Processing file 6700_6800_w_embeddings.csv....
# Processing file 6800_6900_w_embeddings.csv....
# Processing file 6900_7000_w_embeddings.csv....
# Processing file 7000_7100_w_embeddings.csv....
# Processing file 7100_7200_w_embeddings.csv....
# Processing file 7200_7300_w_embeddings.csv....
# Processing file 7300_7400_w_embeddings.csv....
# Processing file 7400_7500_w_embeddings.csv....
# Processing file 7500_7600_w_embeddings.csv....
# Processing file 7600_7700_w_embeddings.csv....
# Processing file 7700_7800_w_embeddings.csv....
# Processing file 7800_7900_w_embeddings.csv....
# Processing file 7900_8000_w_embeddings.csv....
# Processing file 8000_8100_w_embeddings.csv....
# Processing file 8100_8200_w_embeddings.csv....
# Processing file 8200_8300_w_embeddings.csv....
# Processing file 8300_8400_w_embeddings.csv....
# Processing file 8400_8500_w_embeddings.csv....
# Processing file 8500_8600_w_embeddings.csv....
# Processing file 8600_8700_w_embeddings.csv....
# Processing file 8700_8800_w_embeddings.csv....
# Processing file 8800_8900_w_embeddings.csv....
# Processing file 8900_9000_w_embeddings.csv....
# Processing file 9000_9100_w_embeddings.csv....
# Processing file 9100_9200_w_embeddings.csv....
# Processing file 9200_9300_w_embeddings.csv....
# Processing file 9300_9400_w_embeddings.csv....
# Processing file 9400_9500_w_embeddings.csv....
# Processing file 9500_9600_w_embeddings.csv....
# Processing file 9600_9689_w_embeddings.csv....
# Processing file 9689_9789_w_embeddings.csv....
# Processing file 9789_9889_w_embeddings.csv....
# Processing file 9889_9989_w_embeddings.csv....
# Processing file 9989_10089_w_embeddings.csv....
# <ipython-input-38-3538707867>:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(dataframes, ignore_index=True)
# <ipython-input-39-99353420>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   image_df['image_embeddings'] = image_df['image_embeddings'].apply(lambda x: x.reshape(1, -1))

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/book_data/image_embeddings.pkl'  # Replace with the actual path
loaded_df = pd.read_pickle(file_path)

# %%
# Display the first few rows
print(loaded_df.head())

    # Get information about the DataFrame
print(loaded_df.info())

    # See the column names
print(loaded_df.columns)
# Out:
#     Unnamed: 0.2 Unnamed: 0.1 Unnamed: 0                    title isbn_10  \
# 0            0.0        17643      73504  Four Days of You and Me     NaN
# 3            3.0        17663      73573          Jessica of Russ     NaN
# 7            7.0        19325      76688           Tiamat's Wrath     NaN
# 13          13.0        21446      79741             Paranorthern     NaN
# 15          15.0        21513      79854           Shot at Normal     NaN
#
#               isbn_13 publish_date                 key  \
# 0   ['9781492684138']         2020  /books/OL28087551M
# 3   ['9781892784476']         2020  /books/OL28105701M
# 7   ['9780316332897']         2020  /books/OL28940416M
# 13  ['9780358168997']         2021  /books/OL29845365M
# 15  ['9780374380953']         2021  /books/OL29882268M
#
#                                        subjects                    languages  \
# 0                        ["Children's fiction"]  [{'key': '/languages/eng'}]
# 3   ['Fiction, historical', 'Fiction, general']  [{'key': '/languages/eng'}]
# 7         ['Fiction, science fiction, general']  [{'key': '/languages/eng'}]
# 13                       ["Children's fiction"]  [{'key': '/languages/eng'}]
# 15                       ["Children's fiction"]  [{'key': '/languages/eng'}]
#
#    description.value genres       image_id  \
# 0                NaN    NaN  9781492684138
# 3                NaN    NaN  9781892784476
# 7                NaN    NaN  9780316332897
# 13               NaN    NaN  9780358168997
# 15               NaN    NaN  9780374380953
#
#                                             image_url  \
# 0   https://covers.openlibrary.org/b/isbn/97814926...
# 3   https://covers.openlibrary.org/b/isbn/97818927...
# 7   https://covers.openlibrary.org/b/isbn/97803163...
# 13  https://covers.openlibrary.org/b/isbn/97803581...
# 15  https://covers.openlibrary.org/b/isbn/97803743...
#
#                                               image_x  \
# 0   <PIL.Image.Image image mode=RGB size=266x400 a...
# 3   <PIL.Image.Image image mode=RGB size=333x500 a...
# 7   <PIL.Image.Image image mode=RGB size=973x1500 ...
# 13  <PIL.Image.Image image mode=RGB size=150x218 a...
# 15  <PIL.Image.Image image mode=RGB size=333x499 a...
#
#                                               image_y  \
# 0   <PIL.Image.Image image mode=RGB size=266x400 a...
# 3   <PIL.Image.Image image mode=RGB size=333x500 a...
# 7   <PIL.Image.Image image mode=RGB size=973x1500 ...
# 13  <PIL.Image.Image image mode=RGB size=150x218 a...
# 15  <PIL.Image.Image image mode=RGB size=333x499 a...
#
#                                      image_embeddings
# 0   [[0.217918783, -0.425702512, 0.0983703136, -0....
# 3   [[0.0504726507, 0.304955542, 0.171226814, 0.08...
# 7   [[-0.089997679, 0.172076777, -0.101228528, 0.3...
# 13  [[-0.162872955, 0.230873913, 0.10157457, 0.068...
# 15  [[-0.0601121634, -0.0355024189, 0.190376759, 0...
# <class 'pandas.core.frame.DataFrame'>
# Index: 4216 entries, 0 to 9687
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.2       3383 non-null   float64
#  1   Unnamed: 0.1       4216 non-null   object
#  2   Unnamed: 0         4216 non-null   object
#  3   title              4216 non-null   object
#  4   isbn_10            125 non-null    object
#  5   isbn_13            4216 non-null   object
#  6   publish_date       4216 non-null   object
#  7   key                4216 non-null   object
#  8   subjects           4216 non-null   object
#  9   languages          4216 non-null   object
#  10  description.value  80 non-null     object
#  11  genres             1 non-null      object
#  12  image_id           4216 non-null   object
#  13  image_url          4216 non-null   object
#  14  image_x            3383 non-null   object
#  15  image_y            3383 non-null   object
#  16  image_embeddings   4216 non-null   object
# dtypes: float64(1), object(16)
# memory usage: 592.9+ KB
# None
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'title', 'isbn_10',
#        'isbn_13', 'publish_date', 'key', 'subjects', 'languages',
#        'description.value', 'genres', 'image_id', 'image_url', 'image_x',
#        'image_y', 'image_embeddings'],
#       dtype='object')

# %%
query_book_index = 1  # Replace with the index of the book you want to query
query_embedding = loaded_df.iloc[query_book_index]['image_embeddings']

# %%
from scipy.spatial.distance import cosine
import numpy as np

# Reshape the query embedding to be 1-dimensional
query_embedding_1d = query_embedding.reshape(-1)

# Reshape the embeddings in the DataFrame to be 1-dimensional before calculating cosine similarity
# Calculate cosine distances between the query embedding and all other embeddings
similarities = loaded_df['image_embeddings'].apply(lambda embedding: 1 - cosine(query_embedding_1d, embedding.reshape(-1)))

# Add the similarities as a new column to your DataFrame
loaded_df['similarity'] = similarities

# %%
# Sort the DataFrame by similarity in descending order
# Exclude the query book itself from the results
sorted_similar_books = loaded_df.sort_values(by='similarity', ascending=False)

# Display the top N most similar books (excluding the query book at index 0)
# Let's show the top 10 similar books as an example
top_n = 10
print(f"Top {top_n} most similar books to the book at index {query_book_index}:")
# The most similar book will be the query book itself, so we slice from index 1 onwards
display(sorted_similar_books.iloc[1:top_n+1])
# Out:
# Top 10 most similar books to the book at index 1:
#       Unnamed: 0.2 Unnamed: 0.1 Unnamed: 0                    title isbn_10  \
# 6866          66.0      9079266     679955         Sit a Tall Horse     NaN
# 2693          93.0      3612914     402519            Grief Rituals     NaN
# 7415          15.0      9777389     654029       Home and the World     NaN
# 9617           NaN     12663883     956191                   Mullin     NaN
# 3833          33.0      5055210     525263                  Society     NaN
# 3904           4.0      5150495     931162      In the Country Dark     NaN
# 2644          44.0      3561469     159678  Mad Patagonian Part One     NaN
# 1352          52.0      1809690     709372           Dragon's Night     NaN
# 5604           4.0      7346890     288520           Sun Also Rises     NaN
# 1002           2.0      1321197     625854       Saints and Sinners     NaN
#
#                 isbn_13 publish_date                 key  \
# 6866  ['9781885210333']         2020  /books/OL28098717M
# 2693  ['9781951658274']         2022  /books/OL42831369M
# 7415  ['9788186685273']         2020  /books/OL29019413M
# 9617  ['9781732144231']         2020  /books/OL28106675M
# 3833  ['9781736599150']         2021  /books/OL35566844M
# 3904  ['9781940249186']         2020  /books/OL30241665M
# 2644  ['9781955823005']         2021  /books/OL35141497M
# 1352  ['9781943728060']         2020  /books/OL28104276M
# 5604  ['9781950330997']         2022  /books/OL36761013M
# 1002  ['9781639772520']         2022  /books/OL39181021M
#
#                                                subjects  \
# 6866                               ['Fiction, general']
# 2693  ['Fiction, horror', 'Fiction, short stories (s...
# 7415          ['Fiction, historical', 'India, fiction']
# 9617               ['Biography', 'Fiction, historical']
# 3833  ['Fiction, visionary & metaphysical', 'Fiction...
# 3904  ['Crime', 'Fiction, mystery & detective, gener...
# 2644                               ['Fiction, general']
# 1352      ['Fiction, gay', 'Fiction, fantasy, general']
# 5604  ['Fiction, general', 'Fiction, historical, gen...
# 1002                              ['Fiction, westerns']
#
#                         languages description.value genres       image_id  \
# 6866  [{'key': '/languages/eng'}]               NaN    NaN  9781885210333
# 2693  [{'key': '/languages/eng'}]               NaN    NaN  9781951658274
# 7415  [{'key': '/languages/eng'}]               NaN    NaN  9788186685273
# 9617  [{'key': '/languages/eng'}]               NaN    NaN  9781732144231
# 3833  [{'key': '/languages/eng'}]               NaN    NaN  9781736599150
# 3904  [{'key': '/languages/eng'}]               NaN    NaN  9781940249186
# 2644  [{'key': '/languages/eng'}]               NaN    NaN  9781955823005
# 1352  [{'key': '/languages/eng'}]               NaN    NaN  9781943728060
# 5604  [{'key': '/languages/eng'}]               NaN    NaN  9781950330997
# 1002  [{'key': '/languages/eng'}]               NaN    NaN  9781639772520
#
#                                               image_url  \
# 6866  https://covers.openlibrary.org/b/isbn/97818852...
# 2693  https://covers.openlibrary.org/b/isbn/97819516...
# 7415  https://covers.openlibrary.org/b/isbn/97881866...
# 9617  https://covers.openlibrary.org/b/isbn/97817321...
# 3833  https://covers.openlibrary.org/b/isbn/97817365...
# 3904  https://covers.openlibrary.org/b/isbn/97819402...
# 2644  https://covers.openlibrary.org/b/isbn/97819558...
# 1352  https://covers.openlibrary.org/b/isbn/97819437...
# 5604  https://covers.openlibrary.org/b/isbn/97819503...
# 1002  https://covers.openlibrary.org/b/isbn/97816397...
#
#                                                 image_x  \
# 6866  <PIL.Image.Image image mode=RGB size=333x500 a...
# 2693  <PIL.Image.Image image mode=RGB size=313x500 a...
# 7415  <PIL.Image.Image image mode=RGB size=329x500 a...
# 9617                                                NaN
# 3833  <PIL.Image.Image image mode=RGB size=266x400 a...
# 3904  <PIL.Image.Image image mode=RGB size=313x500 a...
# 2644  <PIL.Image.Image image mode=RGB size=333x500 a...
# 1352  <PIL.Image.Image image mode=RGB size=333x500 a...
# 5604  <PIL.Image.Image image mode=RGB size=314x500 a...
# 1002  <PIL.Image.Image image mode=RGB size=313x500 a...
#
#                                                 image_y  \
# 6866  <PIL.Image.Image image mode=RGB size=333x500 a...
# 2693  <PIL.Image.Image image mode=RGB size=313x500 a...
# 7415  <PIL.Image.Image image mode=RGB size=329x500 a...
# 9617                                                NaN
# 3833  <PIL.Image.Image image mode=RGB size=266x400 a...
# 3904  <PIL.Image.Image image mode=RGB size=313x500 a...
# 2644  <PIL.Image.Image image mode=RGB size=333x500 a...
# 1352  <PIL.Image.Image image mode=RGB size=333x500 a...
# 5604  <PIL.Image.Image image mode=RGB size=314x500 a...
# 1002  <PIL.Image.Image image mode=RGB size=313x500 a...
#
#                                        image_embeddings  similarity
# 6866  [[-0.510898113, 0.252963483, 0.356260955, 0.25...    0.703768
# 2693  [[0.370317638, 0.32435286, -0.0879774615, 0.17...    0.682013
# 7415  [[-0.175874263, -0.0386425853, 0.315994769, 0....    0.679220
# 9617  [[0.0455101132, 0.228901029, -0.182094693, 0.3...    0.677788
# 3833  [[0.251824319, -0.00143073406, 0.503302813, -0...    0.670004
# 3904  [[0.340414703, -0.0206347294, 0.36949271, 0.47...    0.665638
# 2644  [[-0.153149337, 0.291618496, 0.133568466, -0.2...    0.662792
# 1352  [[0.0803963393, 0.511007786, 0.206290483, 0.00...    0.660096
# 5604  [[-0.258123308, 0.00550228357, -0.0715105534, ...    0.660061
# 1002  [[-0.093682684, 0.125784934, 0.10113921, 0.330...    0.659017

# %% [markdown]
# Add Search API

# %%
# Install faiss, fastapi and uvicorn
# !pip install faiss-cpu fastapi uvicorn

# Now, the import should work
from fastapi import FastAPI, Request
from transformers import CLIPProcessor, CLIPModel
import faiss
import torch
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Collecting fastapi
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.34.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.11.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (4.14.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.1)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 63.5 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 10.4 MB/s eta 0:00:00
# Downloading uvicorn-0.34.3-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.5 MB/s eta 0:00:00
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: uvicorn, faiss-cpu, starlette, fastapi
# Successfully installed faiss-cpu-1.11.0 fastapi-0.115.12 starlette-0.46.2 uvicorn-0.34.3

# %%
# Ensure embeddings are in a suitable numpy format for FAISS
# If your embeddings are already numpy arrays with consistent dimensions, you might not need the .tolist()
embeddings_np = np.vstack(loaded_df['image_embeddings'].tolist()).astype('float32')

# Get the dimension of the embeddings
d = embeddings_np.shape[1]

# Build a simple IndexFlatL2 index (you can choose a different index type based on your needs)
index = faiss.IndexFlatL2(d)

# Add the embeddings to the index
index.add(embeddings_np)

# Save the index to a file
faiss.write_index(index, "book_index.faiss")

# Create a mapping from FAISS index position to your book key or another identifier
# This allows you to retrieve book information after finding similar items in the index
# For simplicity, we'll use the DataFrame index as the book ID in this example
book_id_map = loaded_df['key'].tolist()

print("FAISS index built and saved as book_index.faiss")
# Out:
# FAISS index built and saved as book_index.faiss

# %%
# Ensure embeddings are in a suitable numpy format for FAISS
# If your embeddings are already numpy arrays with consistent dimensions, you might not need the .tolist()
embeddings_np = np.vstack(loaded_df['image_embeddings'].tolist()).astype('float32')

# Get the dimension of the embeddings
d = embeddings_np.shape[1]

# Build a simple IndexFlatL2 index (you can choose a different index type based on your needs)
index = faiss.IndexFlatL2(d)

# Add the embeddings to the index
index.add(embeddings_np)

# Save the index to a file
faiss.write_index(index, "book_index.faiss")

# Create a mapping from FAISS index position to your book key or another identifier
# This allows you to retrieve book information after finding similar items in the index
# For simplicity, we'll use the DataFrame index as the book ID in this example
book_id_map = loaded_df['key'].tolist()

print("FAISS index built and saved as book_index.faiss")
# Out:
# FAISS index built and saved as book_index.faiss

# %%
app = FastAPI()
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
index = faiss.read_index("book_index.faiss")  # Load the pre-built FAISS index
book_id_map = [...]  # Map from FAISS index position to your book IDs
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
@app.get("/api/search_books")
def search_books(q: str):
  pass

# %%
import faiss, pickle
import numpy as np
import pandas as pd # Import pandas

# 1) Load your embeddings and their corresponding book IDs from the pickled DataFrame.
with open('/content/drive/MyDrive/book_data/image_embeddings.pkl', 'rb') as f:
    loaded_df = pd.read_pickle(f) # Load the DataFrame

# Extract the embeddings column and convert to a numpy array
# Ensure the column 'image_embeddings' contains the actual numpy arrays for embeddings
# The previous step in the notebook already prepared this column.
# We need to stack the individual numpy arrays within the Series.
vectors  = np.vstack(loaded_df['image_embeddings'].values).astype('float32')

# Get the book identifiers (e.g., 'key' column) to map index results back to books
book_ids = loaded_df['key'].tolist() # Use the 'key' column for mapping

# 2) Build the index
index = faiss.IndexFlatL2(vectors.shape[1])
index.add(vectors)

# 3) Save to disk
faiss.write_index(index, 'book_index.faiss')
with open('book_id_map.pkl', 'wb') as f:
    pickle.dump(book_ids, f) # Save the list of book IDs

print("Saved book_index.faiss and book_id_map.pkl")
# Out:
# Saved book_index.faiss and book_id_map.pkl

# %%
import csv, pickle

key_title = {}
with open("/content/drive/MyDrive/book_data/recent_fiction.csv", newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        key = row["key"]         # e.g. "/books/OL123M"
        title = row["title"]     # e.g. "Moby Dick"
        key_title[key] = title

with open("key_title_map.pkl", "wb") as f:
    pickle.dump(key_title, f)
